# %% [markdown]
# <a href="https://colab.research.google.com/github/sarsalejokeirluis-dev/prototype/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
num3 = int(input("Enter the last number"))

if num1 >= num2 and num1 >= num3:
  largest = num1
elif num2 >= num1 and num2 >= num3:
  largest = num2
else:
  largest = num3

print("The largest number is:", largest)
# Out:
# Enter first number 1
# Enter second number2
# Enter the last number3
# The largest number is: 3
